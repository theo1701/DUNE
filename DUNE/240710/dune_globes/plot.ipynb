# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
group = 8

# %%
if group == 1:
    file1 = open("prob_NH_dcp-90_uni_mue_0to10_theta23test.dat", "r")
    file2 = open("prob_NH_dcp+90_uni_mue_0to10_theta23test.dat", "r")
    file3 = open("prob_IH_dcp-90_uni_mue_0to10_theta23test.dat", "r")
    file4 = open("prob_IH_dcp+90_uni_mue_0to10_theta23test.dat", "r")
elif group == 2:
    file1 = open("prob_NH_dcp-90_uni_mubarebar_0to10_theta23test.dat", "r")
    file2 = open("prob_NH_dcp+90_uni_mubarebar_0to10_theta23test.dat", "r")
    file3 = open("prob_IH_dcp-90_uni_mubarebar_0to10_theta23test.dat", "r")
    file4 = open("prob_IH_dcp+90_uni_mubarebar_0to10_theta23test.dat", "r")
elif group == 3:
    file1 = open("prob_NH_dcp-90_uni_mumu_0to10_theta23test.dat", "r")
    file2 = open("prob_NH_dcp+90_uni_mumu_0to10_theta23test.dat", "r")
    file3 = open("prob_IH_dcp-90_uni_mumu_0to10_theta23test.dat", "r")
    file4 = open("prob_IH_dcp+90_uni_mumu_0to10_theta23test.dat", "r")
elif group == 4:
    file1 = open("prob_NH_dcp-90_uni_mubarmubar_0to10_theta23test.dat", "r")
    file2 = open("prob_NH_dcp+90_uni_mubarmubar_0to10_theta23test.dat", "r")
    file3 = open("prob_IH_dcp-90_uni_mubarmubar_0to10_theta23test.dat", "r")
    file4 = open("prob_IH_dcp+90_uni_mubarmubar_0to10_theta23test.dat", "r")
elif group == 5:
    file1 = open("prob_NH_dcp-90_uni_HO_mue.dat", "r")
    file2 = open("prob_NH_dcp-90_uni_LO_mue.dat", "r")
    file3 = open("prob_IH_dcp-90_uni_HO_mue.dat", "r")
    file4 = open("prob_IH_dcp-90_uni_LO_mue.dat", "r")
elif group == 6:
    file1 = open("prob_NH_dcp-90_uni_HO_mubarebar.dat", "r")
    file2 = open("prob_NH_dcp-90_uni_LO_mubarebar.dat", "r")
    file3 = open("prob_IH_dcp-90_uni_HO_mubarebar.dat", "r")
    file4 = open("prob_IH_dcp-90_uni_LO_mubarebar.dat", "r")
elif group == 7:
    file1 = open("prob_NH_dcp+90_uni_HO_mue.dat", "r")
    file2 = open("prob_NH_dcp+90_uni_LO_mue.dat", "r")
    file3 = open("prob_IH_dcp+90_uni_HO_mue.dat", "r")
    file4 = open("prob_IH_dcp+90_uni_LO_mue.dat", "r")
elif group == 8:
    file1 = open("prob_NH_dcp+90_uni_HO_mubarebar.dat", "r")
    file2 = open("prob_NH_dcp+90_uni_LO_mubarebar.dat", "r")
    file3 = open("prob_IH_dcp+90_uni_HO_mubarebar.dat", "r")
    file4 = open("prob_IH_dcp+90_uni_LO_mubarebar.dat", "r")

# %%
def separate_e_p(file):
    e = []
    p = []
    for line in file:
        line = line.replace("\n", "")
        line = line.split(",")
        e.append(float(line[0]))
        p.append(float(line[1]))
    file.close()
    return e, p

# %%
e1, p1 = separate_e_p(file1)
e2, p2 = separate_e_p(file2)
e3, p3 = separate_e_p(file3)
e4, p4 = separate_e_p(file4)

# %%
if group == 1:
    plt.plot(e1, p1, label=r"$P_{\mu e},NH,\delta_{cp}=-90^o$")
    plt.plot(e2, p2, label=r"$P_{\mu e},NH,\delta_{cp}=+90^o$")
    plt.plot(e3, p3, label=r"$P_{\mu e},IH,\delta_{cp}=-90^o$")
    plt.plot(e4, p4, label=r"$P_{\mu e},IH,\delta_{cp}=+90^o$")
elif group == 2:
    plt.plot(e1, p1include , label=r"$P_{\bar{\mu} \bar{e}},NH,\delta_{cp}=-90^o$")
    plt.plot(e2, p2, label=r"$P_{\bar{\mu} \bar{e}},NH,\delta_{cp}=+90^o$")
    plt.plot(e3, p3, label=r"$P_{\bar{\mu} \bar{e}},IH,\delta_{cp}=-90^o$")
    plt.plot(e4, p4, label=r"$P_{\bar{\mu} \bar{e}},IH,\delta_{cp}=+90^o$")
elif group == 3:
    plt.plot(e1, p1, label=r"$P_{\mu \mu},NH,\delta_{cp}=-90^o$")
    plt.plot(e2, p2, label=r"$P_{\mu \mu},NH,\delta_{cp}=+90^o$")
    plt.plot(e3, p3, label=r"$P_{\mu \mu},IH,\delta_{cp}=-90^o$")
    plt.plot(e4, p4, label=r"$P_{\mu \mu},IH,\delta_{cp}=+90^o$")
elif group == 4:
    plt.plot(e1, p1, label=r"$P_{\bar{\mu} \bar{\mu}},NH,\delta_{cp}=-90^o$")
    plt.plot(e2, p2, label=r"$P_{\bar{\mu} \bar{\mu}},NH,\delta_{cp}=+90^o$")
    plt.plot(e3, p3, label=r"$P_{\bar{\mu} \bar{\mu}},IH,\delta_{cp}=-90^o$")
    plt.plot(e4, p4, label=r"$P_{\bar{\mu} \bar{\mu}},IH,\delta_{cp}=+90^o$")
elif group == 5:
    plt.plot(e1, p1, label=r"$P_{\mu e},NH,HO, \delta_{cp}=-90^o$")
    plt.plot(e2, p2, label=r"$P_{\mu e},NH,LO, \delta_{cp}=-90^o$")
    plt.plot(e3, p3, label=r"$P_{\mu e},IH,HO, \delta_{cp}=-90^o$")
    plt.plot(e4, p4, label=r"$P_{\mu e},IH,LO, \delta_{cp}=-90^o$")
elif group == 6:
    plt.plot(e1, p1, label=r"$P_{\bar{\mu} \bar{e}},NH,HO, \delta_{cp}=-90^o$")
    plt.plot(e2, p2, label=r"$P_{\bar{\mu} \bar{e}},NH,LO, \delta_{cp}=-90^o$")
    plt.plot(e3, p3, label=r"$P_{\bar{\mu} \bar{e}},IH,HO, \delta_{cp}=-90^o$")
    plt.plot(e4, p4, label=r"$P_{\bar{\mu} \bar{e}},IH,LO, \delta_{cp}=-90^o$")
elif group == 7:
    plt.plot(e1, p1, label=r"$P_{\mu e},NH,HO, \delta_{cp}=+90^o$")
    plt.plot(e2, p2, label=r"$P_{\mu e},NH,LO, \delta_{cp}=+90^o$")
    plt.plot(e3, p3, label=r"$P_{\mu e},IH,HO, \delta_{cp}=+90^o$")
    plt.plot(e4, p4, label=r"$P_{\mu e},IH,LO, \delta_{cp}=+90^o$")
elif group == 8:
    plt.plot(e1, p1, label=r"$P_{\bar{\mu} \bar{e}},NH,HO, \delta_{cp}=+90^o$")
    plt.plot(e2, p2, label=r"$P_{\bar{\mu} \bar{e}},NH,LO, \delta_{cp}=+90^o$")
    plt.plot(e3, p3, label=r"$P_{\bar{\mu} \bar{e}},IH,HO, \delta_{cp}=+90^o$")
    plt.plot(e4, p4, label=r"$P_{\bar{\mu} \bar{e}},IH,LO, \delta_{cp}=+90^o$")

plt.xlabel("E[GeV]")
plt.ylabel("probability")
plt.legend()
plt.ylim(0, 0.1)
plt.savefig("prob_mubarebar_dcp+90.pdf")
